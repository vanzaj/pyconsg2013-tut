# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
datetime.datetime.now().strftime("%c")
# Out:
# 'Sun Jun  9 23:58:42 2013'

# %%
from IPython.display import Image, HTML
Image(url='https://pycon.sg/static/images/pycon-logo.jpg')
# Out:
# <img src="https://pycon.sg/static/images/pycon-logo.jpg" />

# %%
Image(filename='data/pycon-logo.jpg')

# %%
HTML('<iframe src=https://pycon.sg width=800 height=200>')
# Out:
# <iframe src=https://pycon.sg width=800 height=200>

# %%
import pandas
pandas.core.format.set_option('notebook_repr_html',True)

# %%
from sympy import Symbol, sin, cos
# %load_ext sympy.interactive.ipythonprinting

# %%
x = Symbol('x')
y = Symbol('y')
((x+y)**2).expand()
# Out:
#  2            2
# x  + 2⋅x⋅y + y

# %% [markdown]
# # Switching matplotlib backend

# %%
# restar the kernel if %pylab inline was used
import matplotlib as mpl
import matplotlib.pylab as plt
import numpy as npß
print mpl.rcsetup.all_backends
# Out:
# ['GTK', 'GTKAgg', 'GTKCairo', 'FltkAgg', 'MacOSX', 'QtAgg', 'Qt4Agg', 'TkAgg', 'WX', 'WXAgg', 'CocoaAgg', 'GTK3Cairo', 'GTK3Agg', 'agg', 'cairo', 'emf', 'gdk', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
mpl.use('MacOSX')
# Out:
# /Users/ivan/dev/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:1033: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
x = np.arange(10)

# %%
plt.plot(x, x**2, 'ro-')
plt.title(r'$y = x^2$')

# %%
plt.show()

# %% [markdown]
# # Images in matplotlib

# %%
logo = imread('data/pycon-logo.jpg')
imshow(logo[:,:,2], cmap='hsv')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1088e1cb0>

# %%
logo?

# %% [markdown]
# # Animation

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from IPython.display import clear_output
import time

# %%
x = np.linspace(0,2*pi, 100)
fig, ax = plt.subplots()

for i in range(1,10):
    time.sleep(1)
    ax.plot(x, sin(x + i*pi/10))
    clear_output()
    display(fig)

# %% [markdown]
# ## 3D staff

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
size = 20
x, y = mgrid[-size:size+1, -size:size+1]
g = exp(-(x**2/float(size)+y**2/float(size)))
#g = g / g.sum()

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(1, 1, 1, projection='3d')
p = ax.plot_surface(x, y, g, rstride=4, cstride=4, linewidth=0)
ax.view_init(30, 30)
